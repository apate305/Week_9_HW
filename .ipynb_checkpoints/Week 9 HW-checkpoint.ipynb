# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#modules for statistics
import math
import statistics
from scipy import stats

belize_listings_path = "belize_airbnb_listings copy 2.csv"
belize_df = pd.read_csv(belize_listings_path)
belize_df
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# ...        ...                                                ...        ...
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
# ...

# %% [markdown]
# While the Belize dataset is not normally distributed, act as if it is for the purposes of the homework.
# 1.	Why is assuming normal data an important consideration when answering questions about probability?

# %% [markdown]
# Assuming normal data is important when working with probability because most continuous data is bell-shaped when graphed so normal distribution is considered to be the most important probability distribution.
# Having a normally distributed graph makes it easy to work with and therefore the probability can be determined with more accuracy.

# %% [markdown]
# 2.	Create two histograms in a subplot (vertical or horizontal is fine) that show the distribution of reviews_per_month and number_of_reviews in Belize Airbnb data
#
#
# a.	How do you choose your bin size?

# %% [markdown]
# The number of bins is chosen by taking the square root of the number of rows (number of data), in the specific column and then rounding that number (I got 53 for both histograms below). Then the width of the bins are chosen by taking the range of the data and dividing it by the number of bins (53). I did not do that since the width of the bins are adjusted according to the number of bins anyway. Also I got a really long decimal number so that width would not translate well onto the histogram.

# %%
rows_1 = len(belize_df['reviews_per_month'])
print(rows_1)

min_1 = belize_df['reviews_per_month'].min()
print(min_1)

max_1 = belize_df['reviews_per_month'].max()
print(max_1)
# Out:
# 2796
# 0.01
# 5.92

# %%
rows_2 = len(belize_df['number_of_reviews'])
print(rows_2)

min_2 = belize_df['number_of_reviews'].min()
print(min_2)

max_2 = belize_df['number_of_reviews'].max()
print(max_2)
# Out:
# 2796
# 0
# 316

# %%
#Create histogram of reviews_per_month
plt.subplots(1, 1)
belize_df['reviews_per_month'].hist (bins = 53, color="black", figsize=(20,20))


#Create histogram of number_of_reviews
plt.subplots(1, 2)
belize_df['number_of_reviews'].hist (bins= 53, color="blue", alpha=0.5, figsize=(20,20))



plt.title('Reviews', fontsize = 70)
plt.xlabel('Count of Reviews', fontsize = 40)
plt.ylabel('How many of Counts of each Count of Reviews', fontsize = 40)
plt.tick_params(axis='both', which='major', labelsize=25)

#Show plot
plt.show()


#NOTE BOTH HISTOGRAMS ARE IN THE SUBPLOT, ONE IS JUST REALLY SMALL. ZOOM IN TO SEE. 
#(I tried using subplot function and passed in the rows, columns and location but I could not see the
#histogram for 'reviews per month'.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jl/_v7nhy4x6ns_kxmg8nxmzggr0000gn/T/ipykernel_74785/1480251791.py in <module>
#       1 #Create histogram of reviews_per_month
# ----> 2 plt.subplots(1, 1)
#       3 belize_df['reviews_per_month'].hist (bins = 53, color="black", figsize=(20,20))
#       4
#       5
#
# NameError: name 'plt' is not defined

# %% [markdown]
# 3.	Create a box and whisker plot for availability_365. What does this show you?

# %% [markdown]
# The graph below allows us to see the spread of the data for the total number of days each listing is available for during the year. The box contains all days that are close to the median. The botttom whisker displays the range of the avilabilities below the middle half and the top whisker displays the availabilities that are above the middle half. The points below the botton whisker are the outliers.
#
# About 350 days is considered to be the median amount of days a listing is available for. The top half of the box contains the above-median amount of days which are to be closer to the median, unlike the botton half of the box. The amount of days stretches all the way down to about 5 or 10. And beyond that there are outliers that don't follow the "normal" amoount of available days.

# %%
# Creating plot
fig, ax = plt.subplots(figsize=(20,20))
plt.boxplot(belize_df['availability_365'])

ax.tick_params(axis='both', which='major', labelsize=25)

ax.set_title("Availability_365", fontsize= 40)

# show plot
plt.show()

# %% [markdown]
# 4.	What is the probability that the price for an Airbnb is under $50?

# %%
probability_price = len(belize_df[belize_df["price"] < 50]) / len(belize_df)
print(probability_price)

under_50 = belize_df[belize_df["price"] < 50]
under_50
# Out:
# 0.017525035765379112
#             id                                               name    host_id  \
# 134    4005831      Home away from home,  Shared dormitory, NO AC    9315171
# 148    4304743                DORMITORY Bed #1 of 6, on Maya Ruin    2084006
# 172    4936432      Home away from home,  Shared dormitory, NO AC    9315171
# 189    5509363                      Yaxche Jungle Camp, Dormitory    6960726
# 196    5717367                 Comfortable and Ecological Camping   29641332
# 315   10004488                      Long Term Stay in the country   48785884
# 341   10857678                                        Gecko Cabin   52665457
# 343   11010397                                    Tree Frog Cabin   52665457
# 344   11015225                                         Fern Cabin   52665457
# 346   11057764                                      Jacamar Cabin   52665457
# 348   11058732                                  Blue Morpho Cabin   52665457
# ...

# %% [markdown]
# 4.
#
# a.	What do you notice about these records? Hint: look at the other columns.

# %%
print(belize_df['neighbourhood_group'].value_counts())

print(under_50['neighbourhood_group'].value_counts())



print(belize_df['room_type'].value_counts())

print(under_50['room_type'].value_counts())


#The airbnb prices for the neighborhood group, Corozal, are all either $50 or over and there are no hotel rooms
#that are under $50.
# Out:
# Belize         1574
# Stann Creek     577
# Cayo            505
# Corozal          65
# Toledo           47
# Orange Walk      28
# Name: neighbourhood_group, dtype: int64
# Cayo           21
# Belize         19
# Stann Creek     6
# Toledo          2
# Orange Walk     1
# Name: neighbourhood_group, dtype: int64
# Entire home/apt    1787
# Private room        799
# Hotel room          190
# Shared room          20
# Name: room_type, dtype: int64
# Private room       27
# Entire home/apt    13
# Shared room         9
# Name: room_type, dtype: int64

# %% [markdown]
# 4 b.	What distribution does this data most closely fit?

# %%
#Create histogram of price under 50
under_50['price'].hist (color="blue", figsize=(10, 10))

plt.title('Price Under 50', fontsize = 25)
plt.xlabel('Price', fontsize = 20)
plt.ylabel('How many of each Price', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=10)

#Show plot
plt.show()

# %% [markdown]
# This data most closely fits normal distribution because the bars resemble a bell curve.

# %% [markdown]
# 5.	Calculate the sample variance and standard deviation for all the numerical columns in the same output.

# %%
belize_df.head()

#Numerical Columns: 
    #price
    #minimum_nights
    #number_of_reviews
    #reviews_per_month
    #calculated_host_listings_count
    #availability_365

#Sample variation --statistics.variance(df['col'])

belize_df[["price", "minimum_nights", "number_of_reviews","reviews_per_month", 
          "calculated_host_listings_count", "availability_365", "latitude", "longitude"]].agg(["std", statistics.variance])
# Out:
#                   price  minimum_nights  number_of_reviews  reviews_per_month  \
# std          563.124825        5.669843          30.327768           0.662154
# variance  317109.568066       32.147122         919.773508                NaN
#
#           calculated_host_listings_count  availability_365  latitude  \
# std                            51.711183        120.617632  0.537440
# variance                     2674.046405      14548.613157  0.288841
#
#           longitude
# std        0.383876
# variance   0.147361

# %% [markdown]
# 5a.	Why sample variance and not population variance?

# %% [markdown]
# The dataframe contains many records of airbnb and is therefore too complex so taking the population variance may not be practical.

# %% [markdown]
# 5b.	What is your takeaway for each metric?

# %% [markdown]
# Variance measures how dispersed data points are from the mean.
#
# Variance: The variance of price is very high so the prices must be very spread out. On the other hand, reviews per month has a variance close to 0 so the number of reviews are around the same (close to each other) per month. For latitude and longitude, variance is low so most of the coordinates are near each other.
#
#
# Standard deviation is the square root of the variance.
#
#
# Standard Deviation: The standard deviation of price $563. This means that on average the data points lie $563 away from the mean. Standard deviation makes more sense here compared to variance of price. The standard deviation for minimum nights is 5-6 nights so the points lie 5-6 nights away from the average number of nights.

# %% [markdown]
# 5c.	What are the scales of measurement for each of these values?

# %% [markdown]
# Price--> Ratio  (because price includes a 0 measurement, has measureable intervals)
#
#
# Longitude/Latitude --> Ratio Scale (includes a 0 measurement, has measureable intervals)
#
#
# Minumum_nights, Availablility_365 --> Interval Scale (nights and days are all part of time which have known equal intervals)
#
#
# Number of Reviews, number of reviews per month, calculated_host_listings_count --> ratio scale (includes a 0 measurement, has measureable intervals)

# %% [markdown]
# 6.	What percent of Airbnb listings in Belize are available 360 days a year or more?

# %%
belize_neighbourhood= belize_df[belize_df["neighbourhood_group"] == 'Belize']

belize_neighbourhood_len = len(belize_neighbourhood)

#belize_neighbourhood_len = len(belize_df[belize_df["neighbourhood_group"] == 'Belize'])

(len(belize_neighbourhood[belize_neighbourhood["availability_365"] >= 360]) / belize_neighbourhood_len) * 100

#39% of Airbnb listings in Belize are available 360 days a year or more.
# Out:
# 39.39008894536214

# %%
belize_neighbourhood= belize_df[belize_df["neighbourhood_group"] == 'Belize']
belize_neighbourhood
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# 5       120116                                           Valarosa     604999
# ...        ...                                                ...        ...
# 2788  48266532                Dynamite Apt w/ pool on Beach Front  144478335
# 2789  48279157       Hummingbird pink one bedroom cabin with pool     604999
# 2791  48283996                                     Magical Island   17994012
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
#
# ...

# %% [markdown]
# 6a. 360 days or less?

# %%
(len(belize_neighbourhood[belize_neighbourhood["availability_365"] <= 360]) / belize_neighbourhood_len) * 100

#62% of Airbnb listings in Belize are available for 360 days a year or less.
# Out:
# 61.817026683608645

# %% [markdown]
# 6b.	What distribution does this data most closely fit?

# %%
#Airbnb listings in Belize are available 360 days a year or more
Belize_360plus = belize_neighbourhood[belize_neighbourhood["availability_365"] >= 360]

#Create histogram of reviews_per_month
Belize_360plus['availability_365'].hist (color="blue", figsize=(10, 10))

plt.title('360 Days or More', fontsize = 25)
plt.xlabel('Availability_365', fontsize = 20)
plt.ylabel('Count of Availability_365', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=10)

#Show plot
plt.show()







#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# This data most closely resembles a left skewed (negative) distribution.

# %% [markdown]
# 7.	What minimum night count are 75% of Airnbnb listing in Belize greater than?

# %%
#75% of airbnb listing in Belize have minimum_nights greater than 1
belize_neighbourhood['minimum_nights'].value_counts()
belize_neighbourhood['minimum_nights']

M = belize_neighbourhood['minimum_nights'].to_numpy()
M

np.quantile(M, .25)
# Out:
# 1.0

# %%
# Creating plot
fig, ax = plt.subplots(figsize=(10,10))
plt.boxplot(belize_neighbourhood['minimum_nights'])

ax.tick_params(axis='both', which='major', labelsize=25)

ax.set_title("Minimum Nights", fontsize= 40)

# show plot
plt.show()

# %%
belize_neighbourhood['minimum_nights'].describe()
# Out:
# count    1574.000000
# mean        2.204574
# std         5.396317
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max       180.000000
# Name: minimum_nights, dtype: float64

# %%
belize_neighbourhood['minimum_nights'].value_counts()
# Out:
# 1      688
# 2      440
# 3      351
# 4       56
# 5       20
# 7        9
# 30       3
# 14       2
# 90       1
# 6        1
# 28       1
# 180      1
# 40       1
# Name: minimum_nights, dtype: int64

# %% [markdown]
# The Monty hall problem is a probability illusion. The problem states that if you have 3 doors, one of which has a prize behind it, and you choose the door you’d like to open and are then shown one of the other doors that does not have the prize, then you are better off switching your choice because it increases your probability of winning.
#
# Here is how it works: We may think that by knowing that one of the 3 doors does not have the prize, we have a 50/50 chance of winning. But this is not the case. Here’s why: Before you make your choice, you have 1 in 3 chances of getting the correct door. You also have 2 out of 3 chances of getting the incorrect door. So you have more of a chance of losing than you do winning. After you make your choice, the host will show you what’s behind one  of the two remaining doors—the two remaining doors will most likely be a correct door and an incorrect door since you had more of a chance of choosing the incorrect door to begin with. We also know that the host will never reveal the correct door. So out of the two remaining doors, he will chose to show you the incorrect one. That means the other door will most likely be correct. This is why by switching your choice, you are increasing your probability of winning.
#
# To be exact, you are increasing your probability by 66% compared to 33% which is the probability that you start off with. To prove this, you can make a table of all the possible outcomes. If you add up the amount of times you do not swtich, you only have 33% chance of winning. But if you add up the amount of times you do switch you ahve a 66% chance of winning.

# %% [markdown]
# ![image.png](attachment:image.png)
